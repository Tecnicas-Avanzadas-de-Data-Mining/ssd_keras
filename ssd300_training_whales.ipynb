# %% [markdown]
# # Re-entrenamiento del modelo
#
# Re-entrenamos el modelo SSD con el conjunto de datos de imágenes de *ballenas*. El código esta basado en la implementación con Keras del modelo de entrenamiento original de SSD300 "07+12" en los datasets de Pascal VOC (https://github.com/pierluigiferrari/ssd_keras).

# %%
# usando gpu 1
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import keras
import tensorflow as tf

config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = 0.3
keras.backend.tensorflow_backend.set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

# %matplotlib inline

# %% [markdown]
# ## Parámetros de configuración

# %%
img_height = 300 # Alto de las imágenes de entrada del modelo
img_width = 300 # Ancho de las imágenes de entrada del modelo
img_channels = 3 # Número de canales de color de las imágenes de entrada del modelo
mean_color = [123, 117, 104]
swap_channels = [2, 1, 0]

#n_classes = 20
n_classes = 1 # Nro. de clases positivas, 1 sola (ballenas)

scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # factores de escala del cuadro de anclaje
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05]
scales = scales_pascal

aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # Las proporciones del cuadro

two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300]
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes = False
variances = [0.1, 0.1, 0.2, 0.2]
normalize_coords = True

# %% [markdown]
# ## Construcción del modelo
#
# Llamamos a la función ssd_300() para construir el modelo, cargamos los pesos de VGG-16, utilizamos el optimizador Adam y finalmente compilamos.

# %%
K.clear_session()

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# Cargando los pesos de VGG-16
weights_path = '../ssd_keras/VGG_ILSVRC_16_layers_fc_reduced.h5'
model.load_weights(weights_path, by_name=True)

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

model.summary()
# Out:
# WARNING:tensorflow:From /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# tracking <tf.Variable 'conv4_3_norm/conv4_3_norm_gamma:0' shape=(512,) dtype=float32> gamma
# WARNING:tensorflow:From /home/aalejo/proyectos/ssd_keras_forked/keras_loss_function/keras_ssd_loss.py:133: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/aalejo/proyectos/ssd_keras_forked/keras_loss_function/keras_ssd_loss.py:74: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/aalejo/proyectos/ssd_keras_forked/keras_loss_function/keras_ssd_loss.py:166: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# identity_layer (Lambda)         (None, 300, 300, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# input_mean_normalization (Lambd (None, 300, 300, 3)  0           identity_layer[0][0]
# __________________________________________________________________________________________________
# input_channel_swap (Lambda)     (None, 300, 300, 3)  0           input_mean_normalization[0][0]
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, 300, 300, 64) 1792        input_channel_swap[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 300, 300, 64) 36928       conv1_1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 150, 150, 64) 0           conv1_2[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 150, 150, 128 73856       pool1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 150, 150, 128 147584      conv2_1[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 75, 75, 128)  0           conv2_2[0][0]
# __________________________________________________________________________________________________
# conv3_1 (Conv2D)                (None, 75, 75, 256)  295168      pool2[0][0]
# __________________________________________________________________________________________________
# conv3_2 (Conv2D)                (None, 75, 75, 256)  590080      conv3_1[0][0]
# __________________________________________________________________________________________________
# conv3_3 (Conv2D)                (None, 75, 75, 256)  590080      conv3_2[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 38, 38, 256)  0           conv3_3[0][0]
# __________________________________________________________________________________________________
# conv4_1 (Conv2D)                (None, 38, 38, 512)  1180160     pool3[0][0]
# __________________________________________________________________________________________________
# conv4_2 (Conv2D)                (None, 38, 38, 512)  2359808     conv4_1[0][0]
# __________________________________________________________________________________________________
# conv4_3 (Conv2D)                (None, 38, 38, 512)  2359808     conv4_2[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 19, 19, 512)  0           conv4_3[0][0]
# __________________________________________________________________________________________________
# conv5_1 (Conv2D)                (None, 19, 19, 512)  2359808     pool4[0][0]
# __________________________________________________________________________________________________
# conv5_2 (Conv2D)                (None, 19, 19, 512)  2359808     conv5_1[0][0]
# __________________________________________________________________________________________________
# conv5_3 (Conv2D)                (None, 19, 19, 512)  2359808     conv5_2[0][0]
# __________________________________________________________________________________________________
# pool5 (MaxPooling2D)            (None, 19, 19, 512)  0           conv5_3[0][0]
# __________________________________________________________________________________________________
# fc6 (Conv2D)                    (None, 19, 19, 1024) 4719616     pool5[0][0]
# __________________________________________________________________________________________________
# fc7 (Conv2D)                    (None, 19, 19, 1024) 1049600     fc6[0][0]
# __________________________________________________________________________________________________
# conv6_1 (Conv2D)                (None, 19, 19, 256)  262400      fc7[0][0]
# __________________________________________________________________________________________________
# conv6_padding (ZeroPadding2D)   (None, 21, 21, 256)  0           conv6_1[0][0]
# __________________________________________________________________________________________________
# conv6_2 (Conv2D)                (None, 10, 10, 512)  1180160     conv6_padding[0][0]
# __________________________________________________________________________________________________
# conv7_1 (Conv2D)                (None, 10, 10, 128)  65664       conv6_2[0][0]
# __________________________________________________________________________________________________
# conv7_padding (ZeroPadding2D)   (None, 12, 12, 128)  0           conv7_1[0][0]
# __________________________________________________________________________________________________
# conv7_2 (Conv2D)                (None, 5, 5, 256)    295168      conv7_padding[0][0]
# __________________________________________________________________________________________________
# conv8_1 (Conv2D)                (None, 5, 5, 128)    32896       conv7_2[0][0]
# __________________________________________________________________________________________________
# conv8_2 (Conv2D)                (None, 3, 3, 256)    295168      conv8_1[0][0]
# __________________________________________________________________________________________________
# conv9_1 (Conv2D)                (None, 3, 3, 128)    32896       conv8_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm (L2Normalization)  (None, 38, 38, 512)  512         conv4_3[0][0]
# __________________________________________________________________________________________________
# conv9_2 (Conv2D)                (None, 1, 1, 256)    295168      conv9_1[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_conf (Conv2D) (None, 38, 38, 8)    36872       conv4_3_norm[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_conf (Conv2D)          (None, 19, 19, 12)   110604      fc7[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_conf (Conv2D)      (None, 10, 10, 12)   55308       conv6_2[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_conf (Conv2D)      (None, 5, 5, 12)     27660       conv7_2[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_conf (Conv2D)      (None, 3, 3, 8)      18440       conv8_2[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_conf (Conv2D)      (None, 1, 1, 8)      18440       conv9_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_loc (Conv2D)  (None, 38, 38, 16)   73744       conv4_3_norm[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_loc (Conv2D)           (None, 19, 19, 24)   221208      fc7[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_loc (Conv2D)       (None, 10, 10, 24)   110616      conv6_2[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_loc (Conv2D)       (None, 5, 5, 24)     55320       conv7_2[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_loc (Conv2D)       (None, 3, 3, 16)     36880       conv8_2[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_loc (Conv2D)       (None, 1, 1, 16)     36880       conv9_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_conf_reshape  (None, 5776, 2)      0           conv4_3_norm_mbox_conf[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_conf_reshape (Reshape) (None, 2166, 2)      0           fc7_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_conf_reshape (Resh (None, 600, 2)       0           conv6_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_conf_reshape (Resh (None, 150, 2)       0           conv7_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_conf_reshape (Resh (None, 36, 2)        0           conv8_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_conf_reshape (Resh (None, 4, 2)         0           conv9_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_priorbox (Anc (None, 38, 38, 4, 8) 0           conv4_3_norm_mbox_loc[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_priorbox (AnchorBoxes) (None, 19, 19, 6, 8) 0           fc7_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_priorbox (AnchorBo (None, 10, 10, 6, 8) 0           conv6_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_priorbox (AnchorBo (None, 5, 5, 6, 8)   0           conv7_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_priorbox (AnchorBo (None, 3, 3, 4, 8)   0           conv8_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_priorbox (AnchorBo (None, 1, 1, 4, 8)   0           conv9_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (None, 8732, 2)      0           conv4_3_norm_mbox_conf_reshape[0]
#                                                                  fc7_mbox_conf_reshape[0][0]
#                                                                  conv6_2_mbox_conf_reshape[0][0]
#                                                                  conv7_2_mbox_conf_reshape[0][0]
#                                                                  conv8_2_mbox_conf_reshape[0][0]
#                                                                  conv9_2_mbox_conf_reshape[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_loc_reshape ( (None, 5776, 4)      0           conv4_3_norm_mbox_loc[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_loc_reshape (Reshape)  (None, 2166, 4)      0           fc7_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_loc_reshape (Resha (None, 600, 4)       0           conv6_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_loc_reshape (Resha (None, 150, 4)       0           conv7_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_loc_reshape (Resha (None, 36, 4)        0           conv8_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_loc_reshape (Resha (None, 4, 4)         0           conv9_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_priorbox_resh (None, 5776, 8)      0           conv4_3_norm_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_priorbox_reshape (Resh (None, 2166, 8)      0           fc7_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_priorbox_reshape ( (None, 600, 8)       0           conv6_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_priorbox_reshape ( (None, 150, 8)       0           conv7_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_priorbox_reshape ( (None, 36, 8)        0           conv8_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_priorbox_reshape ( (None, 4, 8)         0           conv9_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# mbox_conf_softmax (Activation)  (None, 8732, 2)      0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (None, 8732, 4)      0           conv4_3_norm_mbox_loc_reshape[0][
#                                                                  fc7_mbox_loc_reshape[0][0]
#                                                                  conv6_2_mbox_loc_reshape[0][0]
#                                                                  conv7_2_mbox_loc_reshape[0][0]
#                                                                  conv8_2_mbox_loc_reshape[0][0]
#                                                                  conv9_2_mbox_loc_reshape[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (None, 8732, 8)      0           conv4_3_norm_mbox_priorbox_reshap
#                                                                  fc7_mbox_priorbox_reshape[0][0]
#                                                                  conv6_2_mbox_priorbox_reshape[0][
#                                                                  conv7_2_mbox_priorbox_reshape[0][
#                                                                  conv8_2_mbox_priorbox_reshape[0][
#                                                                  conv9_2_mbox_priorbox_reshape[0][
# __________________________________________________________________________________________________
# predictions (Concatenate)       (None, 8732, 14)     0           mbox_conf_softmax[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# ==================================================================================================
# Total params: 23,745,908
# Trainable params: 23,745,908
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Generador de datos
#
# Aqui es donde definimos las rutas de archivos del conjunto de datos de ballenas, las anotaciones XML, y la lista de nombres de las imágenes, creadas en el notebook [xml_annotations.ipynb](xml_annotations.ipynb).
#
# Cargamos el dataset completo en memoria reduciendo el tiempo de acceso a cada imagen considerablemente.

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages (4.4.1)

# %%
# Instanciando 2 objetos `DataGenerator`: Uno para entrenamiento y otro para validación.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# Revisamos las anotaciones XML

whales_images_dir_trainval = '../ssd_keras/datasets/whales/train/train/' # JPGs
whales_annotations_dir = '../ssd_keras/datasets/whales/annotations/' # XMLs
whales_train_image_set_filename = '../ssd_keras/datasets/whales/train.txt' # nombres por linea sin extension
whales_val_image_set_filename = '../ssd_keras/datasets/whales/val.txt' # nombres por linea sin extension

classes = ['background','whale']

train_dataset.parse_xml(images_dirs=[whales_images_dir_trainval],
                        image_set_filenames=[whales_train_image_set_filename],
                        annotations_dirs=[whales_annotations_dir],
                        classes=classes,
                        include_classes='all',
                        exclude_truncated=False,
                        exclude_difficult=False,
                        ret=False)

val_dataset.parse_xml(images_dirs=[whales_images_dir_trainval],
                      image_set_filenames=[whales_val_image_set_filename],
                      annotations_dirs=[whales_annotations_dir],
                      classes=classes,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=True,
                      ret=False)


test_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

whales_images_dir_test = '../ssd_keras/datasets/whales/test/test2/'
whales_test_image_set_filename = '../ssd_keras/datasets/whales/test.txt'

test_dataset.parse_xml(images_dirs=[whales_images_dir_test],
                  image_set_filenames=[whales_test_image_set_filename],
                  annotations_dirs=[whales_annotations_dir],
                  classes=classes,
                  include_classes='all',
                  exclude_truncated=False,
                  exclude_difficult=False,
                  ret=False)
# Out:
# Processing image set 'train.txt': 100%|██████████| 1000/1000 [00:00<00:00, 1581.90it/s]
# Loading images into memory: 100%|██████████| 1000/1000 [00:04<00:00, 234.90it/s]
# Processing image set 'val.txt': 100%|██████████| 200/200 [00:00<00:00, 1553.56it/s]
# Loading images into memory: 100%|██████████| 200/200 [00:00<00:00, 231.41it/s]
# Processing image set 'test.txt': 100%|██████████| 39/39 [00:00<00:00, 1409.28it/s]
# Loading images into memory: 100%|██████████| 39/39 [00:00<00:00, 91.48it/s]

# %%
batch_size = 16
#batch_size = 2

# Transformación e incremento de datos
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# Para el generador de validacion
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Nro. de imagenes en el dataset de entrenamiento:\t{:>6}".format(train_dataset_size))
print("Nro. de imagenes en el dataset de validación:\t{:>6}".format(val_dataset_size))
# Out:
# Nro. de imagenes en el dataset de entrenamiento:	  1000
# Nro. de imagenes en el dataset de validación:	   200

# %% [markdown]
# ## Parámetros restantes
#
# Definimos la forma en que la razón de aprendizaje cambiará a lo largo del entrenamiento, también se guardan los modelos al finalizar cada época.

# %%
# Definiendo calendario de razón de aprendizaje
def lr_schedule(epoch):
    if epoch < 80:
        return 0.001
    elif epoch < 100:
        return 0.0001
    else:
        return 0.00001

# %%
from eval_utils.average_precision_evaluator import Evaluator
from keras.callbacks import Callback

class PrintAP(Callback):
    def on_epoch_end(self, batch, logs=None):
        evaluator = Evaluator(model=model,
                          n_classes=1,
                          data_generator=test_dataset,
                          model_mode='training')

        results = evaluator(img_height=img_height,
                            img_width=img_width,
                            batch_size=8,
                            data_generator_mode='resize',
                            round_confidences=False,
                            matching_iou_threshold=0.5,
                            border_pixels='include',
                            sorting_algorithm='quicksort',
                            average_precision_mode='sample',
                            num_recall_points=11,
                            ignore_neutral_boxes=True,
                            return_precisions=True,
                            return_recalls=True,
                            return_average_precisions=True,
                            verbose=True)

        mean_average_precision, average_precisions, precisions, recalls = results

        for i in range(1, len(average_precisions)):
            print("{:<14}{:<6}{}".format(classes[i], 'AP', round(average_precisions[i], 3)))
            print()
            print("{:<14}{:<6}{}".format('','mAP', round(mean_average_precision, 3)))

# %%
# Definiendo otros callbacks.

model_checkpoint = ModelCheckpoint(filepath='ssd300_whales_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
#model_checkpoint.best = 0.73638

csv_logger = CSVLogger(filename='ssd300_whales_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

print_ap = PrintAP()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan,print_ap]

# %% [markdown]
# ## Entrenamiento
#
# Entrenamos 1000 pasos en 120 épocas.

# %%
initial_epoch   = 0 # para resumir se inicia desde el ultimo paso ejecutado
final_epoch     = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# WARNING:tensorflow:From /home/aalejo/anaconda3/envs/dl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 740s 740ms/step - loss: 5.3867 - val_loss: 2.5552
#
# Epoch 00001: val_loss improved from inf to 2.55518, saving model to ssd300_whales_epoch-01_loss-5.3930_val_loss-2.5552.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:06<00:00,  1.27s/it]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 7800/7800 [00:00<00:00, 22827.88it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.478
#
#               mAP   0.478
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 642s 642ms/step - loss: 2.8164 - val_loss: 1.9974
#
# Epoch 00002: val_loss improved from 2.55518 to 1.99739, saving model to ssd300_whales_epoch-02_loss-2.8150_val_loss-1.9974.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  7.79it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 855/855 [00:00<00:00, 4952.72it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.751
#
#               mAP   0.751
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 654s 654ms/step - loss: 2.3621 - val_loss: 1.6940
#
# Epoch 00003: val_loss improved from 1.99739 to 1.69404, saving model to ssd300_whales_epoch-03_loss-2.3623_val_loss-1.6940.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  7.08it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 750/750 [00:00<00:00, 5365.34it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.839
#
#               mAP   0.839
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 656s 656ms/step - loss: 2.0600 - val_loss: 1.4322
#
# Epoch 00004: val_loss improved from 1.69404 to 1.43224, saving model to ssd300_whales_epoch-04_loss-2.0604_val_loss-1.4322.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  7.76it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 499/499 [00:00<00:00, 7314.91it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.872
#
#               mAP   0.872
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 676s 676ms/step - loss: 1.8674 - val_loss: 1.5039
#
# Epoch 00005: val_loss did not improve from 1.43224
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.50it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 225/225 [00:00<00:00, 7691.39it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.824
#
#               mAP   0.824
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 655s 655ms/step - loss: 1.7546 - val_loss: 1.1349
#
# Epoch 00006: val_loss improved from 1.43224 to 1.13494, saving model to ssd300_whales_epoch-06_loss-1.7553_val_loss-1.1349.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.93it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 257/257 [00:00<00:00, 2593.89it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.835
#
#               mAP   0.835
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 655s 655ms/step - loss: 1.5973 - val_loss: 1.1320
#
# Epoch 00007: val_loss improved from 1.13494 to 1.13198, saving model to ssd300_whales_epoch-07_loss-1.5988_val_loss-1.1320.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  8.35it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 185/185 [00:00<00:00, 4415.06it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.89
#
#               mAP   0.89
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 682s 682ms/step - loss: 1.5136 - val_loss: 1.1211
#
# Epoch 00008: val_loss improved from 1.13198 to 1.12106, saving model to ssd300_whales_epoch-08_loss-1.5132_val_loss-1.1211.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.91it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 152/152 [00:00<00:00, 11804.44it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.845
#
#               mAP   0.845
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 656s 656ms/step - loss: 1.4325 - val_loss: 0.9160
#
# Epoch 00009: val_loss improved from 1.12106 to 0.91604, saving model to ssd300_whales_epoch-09_loss-1.4317_val_loss-0.9160.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.53it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 139/139 [00:00<00:00, 7385.83it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.816
#
#               mAP   0.816
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 659s 659ms/step - loss: 1.3989 - val_loss: 0.9410
#
# Epoch 00010: val_loss did not improve from 0.91604
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.60it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 109/109 [00:00<00:00, 5098.12it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 658s 658ms/step - loss: 1.3531 - val_loss: 0.8075
#
# Epoch 00011: val_loss improved from 0.91604 to 0.80749, saving model to ssd300_whales_epoch-11_loss-1.3527_val_loss-0.8075.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.75it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 129/129 [00:00<00:00, 10311.31it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.896
#
#               mAP   0.896
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 644s 644ms/step - loss: 1.3360 - val_loss: 0.8984
#
# Epoch 00012: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.03it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 99/99 [00:00<00:00, 3728.40it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.887
#
#               mAP   0.887
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 625s 625ms/step - loss: 1.2952 - val_loss: 0.8307
#
# Epoch 00013: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.63it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 76/76 [00:00<00:00, 5258.71it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 651s 651ms/step - loss: 1.2606 - val_loss: 1.0016
#
# Epoch 00014: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.32it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 105/105 [00:00<00:00, 6393.38it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.852
#
#               mAP   0.852
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 650s 650ms/step - loss: 1.2474 - val_loss: 0.9793
#
# Epoch 00015: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.37it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 176/176 [00:00<00:00, 3101.68it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.813
#
#               mAP   0.813
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 648s 648ms/step - loss: 1.2533 - val_loss: 0.8818
#
# Epoch 00016: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.87it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 127/127 [00:00<00:00, 4602.71it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.889
#
#               mAP   0.889
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 650s 650ms/step - loss: 1.2401 - val_loss: 0.9646
#
# Epoch 00017: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.30it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 87/87 [00:00<00:00, 3852.74it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.893
#
#               mAP   0.893
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 676s 676ms/step - loss: 1.2175 - val_loss: 1.0137
#
# Epoch 00018: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.16it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 101/101 [00:00<00:00, 11448.08it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.859
#
#               mAP   0.859
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 638s 638ms/step - loss: 1.2068 - val_loss: 1.2220
#
# Epoch 00019: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.20it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 85/85 [00:00<00:00, 11731.74it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 659s 659ms/step - loss: 1.1872 - val_loss: 0.9594
#
# Epoch 00020: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.67it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 123/123 [00:00<00:00, 6076.12it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.887
#
#               mAP   0.887
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 656s 656ms/step - loss: 1.1812 - val_loss: 0.9602
#
# Epoch 00021: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.56it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 112/112 [00:00<00:00, 3844.36it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.862
#
#               mAP   0.862
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 678s 678ms/step - loss: 1.1692 - val_loss: 0.8209
#
# Epoch 00022: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.52it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 117/117 [00:00<00:00, 6160.35it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.894
#
#               mAP   0.894
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 688s 688ms/step - loss: 1.1857 - val_loss: 0.8570
#
# Epoch 00023: val_loss did not improve from 0.80749
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.22it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 86/86 [00:00<00:00, 6879.84it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 663s 663ms/step - loss: 1.1702 - val_loss: 0.7576
#
# Epoch 00024: val_loss improved from 0.80749 to 0.75760, saving model to ssd300_whales_epoch-24_loss-1.1691_val_loss-0.7576.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.24it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 148/148 [00:00<00:00, 7666.41it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.905
#
#               mAP   0.905
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 656s 656ms/step - loss: 1.1667 - val_loss: 0.7315
#
# Epoch 00025: val_loss improved from 0.75760 to 0.73150, saving model to ssd300_whales_epoch-25_loss-1.1658_val_loss-0.7315.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.12it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 127/127 [00:00<00:00, 5539.42it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 801s 801ms/step - loss: 1.1779 - val_loss: 0.9397
#
# Epoch 00026: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.21it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 111/111 [00:00<00:00, 5634.57it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.864
#
#               mAP   0.864
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 733s 733ms/step - loss: 1.1323 - val_loss: 0.9020
#
# Epoch 00027: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.87it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 101/101 [00:00<00:00, 6035.92it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.869
#
#               mAP   0.869
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 724s 724ms/step - loss: 1.1435 - val_loss: 0.7436
#
# Epoch 00028: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.05it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 95/95 [00:00<00:00, 5872.38it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.898
#
#               mAP   0.898
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 779s 779ms/step - loss: 1.1326 - val_loss: 0.7440
#
# Epoch 00029: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.86it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 85/85 [00:00<00:00, 8804.60it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.895
#
#               mAP   0.895
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 697s 697ms/step - loss: 1.1508 - val_loss: 0.8624
#
# Epoch 00030: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.51it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 93/93 [00:00<00:00, 3680.92it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.902
#
#               mAP   0.902
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 642s 642ms/step - loss: 1.1424 - val_loss: 0.9228
#
# Epoch 00031: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.63it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 138/138 [00:00<00:00, 7546.56it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.889
#
#               mAP   0.889
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 652s 652ms/step - loss: 1.1180 - val_loss: 0.9374
#
# Epoch 00032: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  8.69it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 92/92 [00:00<00:00, 5252.44it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.863
#
#               mAP   0.863
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 638s 638ms/step - loss: 1.1249 - val_loss: 0.7680
#
# Epoch 00033: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.19it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 114/114 [00:00<00:00, 5374.23it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.9
#
#               mAP   0.9
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 651s 651ms/step - loss: 1.1050 - val_loss: 0.8564
#
# Epoch 00034: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.47it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 81/81 [00:00<00:00, 5072.47it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 656s 656ms/step - loss: 1.1122 - val_loss: 0.8571
#
# Epoch 00035: val_loss did not improve from 0.73150
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  8.86it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 69/69 [00:00<00:00, 6214.05it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 653s 653ms/step - loss: 1.1106 - val_loss: 0.7140
#
# Epoch 00036: val_loss improved from 0.73150 to 0.71401, saving model to ssd300_whales_epoch-36_loss-1.1110_val_loss-0.7140.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.88it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 99/99 [00:00<00:00, 2450.87it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.894
#
#               mAP   0.894
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 676s 676ms/step - loss: 1.1141 - val_loss: 0.8839
#
# Epoch 00037: val_loss did not improve from 0.71401
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.60it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 78/78 [00:00<00:00, 4750.47it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.902
#
#               mAP   0.902
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 652s 652ms/step - loss: 1.0943 - val_loss: 0.7788
#
# Epoch 00038: val_loss did not improve from 0.71401
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.83it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 103/103 [00:00<00:00, 9354.38it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.907
#
#               mAP   0.907
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 678s 678ms/step - loss: 1.1022 - val_loss: 0.8575
#
# Epoch 00039: val_loss did not improve from 0.71401
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  8.88it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 112/112 [00:00<00:00, 6136.59it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.867
#
#               mAP   0.867
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 652s 652ms/step - loss: 1.1139 - val_loss: 0.8239
#
# Epoch 00040: val_loss did not improve from 0.71401
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.02it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 122/122 [00:00<00:00, 6875.63it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.892
#
#               mAP   0.892
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 648s 648ms/step - loss: 1.0951 - val_loss: 0.7965
#
# Epoch 00041: val_loss did not improve from 0.71401
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 12.22it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 83/83 [00:00<00:00, 5574.05it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.892
#
#               mAP   0.892
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 673s 673ms/step - loss: 1.0951 - val_loss: 1.0312
#
# Epoch 00042: val_loss did not improve from 0.71401
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.11it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 110/110 [00:00<00:00, 5266.46it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.9
#
#               mAP   0.9
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 654s 654ms/step - loss: 1.0901 - val_loss: 1.1301
#
# Epoch 00043: val_loss did not improve from 0.71401
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.21it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 98/98 [00:00<00:00, 7420.60it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.813
#
#               mAP   0.813
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 656s 656ms/step - loss: 1.0957 - val_loss: 0.7076
#
# Epoch 00044: val_loss improved from 0.71401 to 0.70762, saving model to ssd300_whales_epoch-44_loss-1.0962_val_loss-0.7076.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.34it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 76/76 [00:00<00:00, 6744.68it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.892
#
#               mAP   0.892
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 674s 674ms/step - loss: 1.0874 - val_loss: 0.7658
#
# Epoch 00045: val_loss did not improve from 0.70762
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.42it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 76/76 [00:00<00:00, 5297.86it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 653s 653ms/step - loss: 1.0791 - val_loss: 0.7029
#
# Epoch 00046: val_loss improved from 0.70762 to 0.70290, saving model to ssd300_whales_epoch-46_loss-1.0788_val_loss-0.7029.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.42it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 129/129 [00:00<00:00, 8312.57it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.88
#
#               mAP   0.88
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 650s 650ms/step - loss: 1.0959 - val_loss: 0.7955
#
# Epoch 00047: val_loss did not improve from 0.70290
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.71it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 111/111 [00:00<00:00, 14586.83it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.898
#
#               mAP   0.898
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 652s 652ms/step - loss: 1.0776 - val_loss: 0.7707
#
# Epoch 00048: val_loss did not improve from 0.70290
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.00it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 72/72 [00:00<00:00, 8148.67it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.816
#
#               mAP   0.816
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 654s 654ms/step - loss: 1.0849 - val_loss: 0.7386
#
# Epoch 00049: val_loss did not improve from 0.70290
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.56it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 91/91 [00:00<00:00, 7197.74it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.856
#
#               mAP   0.856
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 644s 644ms/step - loss: 1.0945 - val_loss: 0.6876
#
# Epoch 00050: val_loss improved from 0.70290 to 0.68758, saving model to ssd300_whales_epoch-50_loss-1.0948_val_loss-0.6876.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.84it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 78/78 [00:00<00:00, 8709.75it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.902
#
#               mAP   0.902
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 679s 679ms/step - loss: 1.0639 - val_loss: 0.7441
#
# Epoch 00051: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.51it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 76/76 [00:00<00:00, 7551.22it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.892
#
#               mAP   0.892
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 648s 648ms/step - loss: 1.0728 - val_loss: 0.7242
#
# Epoch 00052: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.72it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 84/84 [00:00<00:00, 5337.56it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 645s 645ms/step - loss: 1.0779 - val_loss: 0.7345
#
# Epoch 00053: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.71it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 91/91 [00:00<00:00, 2700.76it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 680s 680ms/step - loss: 1.0746 - val_loss: 0.7165
#
# Epoch 00054: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.03it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 84/84 [00:00<00:00, 8388.21it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.881
#
#               mAP   0.881
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 673s 673ms/step - loss: 1.0717 - val_loss: 0.8212
#
# Epoch 00055: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.26it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 103/103 [00:00<00:00, 2934.49it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.893
#
#               mAP   0.893
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 659s 659ms/step - loss: 1.0921 - val_loss: 0.8758
#
# Epoch 00056: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.02it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 70/70 [00:00<00:00, 2696.29it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 647s 647ms/step - loss: 1.0674 - val_loss: 0.9748
#
# Epoch 00057: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.86it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 90/90 [00:00<00:00, 8308.66it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.87
#
#               mAP   0.87
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 654s 654ms/step - loss: 1.0704 - val_loss: 0.8194
#
# Epoch 00058: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.46it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 114/114 [00:00<00:00, 3516.36it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.886
#
#               mAP   0.886
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 646s 646ms/step - loss: 1.0765 - val_loss: 0.7574
#
# Epoch 00059: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.84it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 81/81 [00:00<00:00, 13687.55it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.883
#
#               mAP   0.883
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 645s 645ms/step - loss: 1.0649 - val_loss: 0.7517
#
# Epoch 00060: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.38it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 102/102 [00:00<00:00, 12454.34it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.803
#
#               mAP   0.803
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 651s 651ms/step - loss: 1.0600 - val_loss: 0.8464
#
# Epoch 00061: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.69it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 145/145 [00:00<00:00, 7815.54it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.86
#
#               mAP   0.86
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 650s 650ms/step - loss: 1.0736 - val_loss: 0.9290
#
# Epoch 00062: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.80it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 89/89 [00:00<00:00, 8239.37it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.9
#
#               mAP   0.9
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 648s 648ms/step - loss: 1.0523 - val_loss: 0.8375
#
# Epoch 00063: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.19it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 92/92 [00:00<00:00, 9896.79it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 651s 651ms/step - loss: 1.0573 - val_loss: 0.8498
#
# Epoch 00064: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.02it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 78/78 [00:00<00:00, 11694.57it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 655s 655ms/step - loss: 1.0664 - val_loss: 0.7846
#
# Epoch 00065: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.24it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 82/82 [00:00<00:00, 3440.98it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.895
#
#               mAP   0.895
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 650s 650ms/step - loss: 1.0565 - val_loss: 0.7477
#
# Epoch 00066: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  8.25it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 89/89 [00:00<00:00, 8798.69it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.871
#
#               mAP   0.871
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 648s 648ms/step - loss: 1.0507 - val_loss: 0.7346
#
# Epoch 00067: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.15it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 83/83 [00:00<00:00, 6831.25it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.894
#
#               mAP   0.894
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 632s 632ms/step - loss: 1.0728 - val_loss: 0.7216
#
# Epoch 00068: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.41it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 72/72 [00:00<00:00, 5074.10it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.88
#
#               mAP   0.88
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 647s 647ms/step - loss: 1.0558 - val_loss: 0.7805
#
# Epoch 00069: val_loss did not improve from 0.68758
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.31it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 93/93 [00:00<00:00, 6495.65it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 650s 650ms/step - loss: 1.0525 - val_loss: 0.6874
#
# Epoch 00070: val_loss improved from 0.68758 to 0.68740, saving model to ssd300_whales_epoch-70_loss-1.0528_val_loss-0.6874.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.81it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 72/72 [00:00<00:00, 8269.16it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 648s 648ms/step - loss: 1.0568 - val_loss: 0.8210
#
# Epoch 00071: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.62it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 84/84 [00:00<00:00, 8105.49it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.885
#
#               mAP   0.885
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 683s 683ms/step - loss: 1.0488 - val_loss: 0.8222
#
# Epoch 00072: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.14it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 73/73 [00:00<00:00, 5671.65it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.885
#
#               mAP   0.885
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 652s 652ms/step - loss: 1.0414 - val_loss: 1.1002
#
# Epoch 00073: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.63it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 89/89 [00:00<00:00, 5591.74it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.881
#
#               mAP   0.881
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 659s 659ms/step - loss: 1.0484 - val_loss: 1.0056
#
# Epoch 00074: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.76it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 91/91 [00:00<00:00, 6831.85it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.882
#
#               mAP   0.882
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 646s 646ms/step - loss: 1.0392 - val_loss: 1.0196
#
# Epoch 00075: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.72it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 76/76 [00:00<00:00, 9995.21it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.816
#
#               mAP   0.816
# Epoch 76/120
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 654s 654ms/step - loss: 1.0407 - val_loss: 0.6946
#
# Epoch 00076: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.14it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 94/94 [00:00<00:00, 5491.99it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 77/120
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 635s 635ms/step - loss: 1.0531 - val_loss: 0.7967
#
# Epoch 00077: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.38it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 86/86 [00:00<00:00, 7395.09it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.863
#
#               mAP   0.863
# Epoch 78/120
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 644s 644ms/step - loss: 1.0444 - val_loss: 0.8425
#
# Epoch 00078: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.89it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 64/64 [00:00<00:00, 8152.19it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 79/120
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 647s 647ms/step - loss: 1.0431 - val_loss: 0.8380
#
# Epoch 00079: val_loss did not improve from 0.68740
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.96it/s]
# ...
# 1000/1000 [==============================] - 679s 679ms/step - loss: 0.7892 - val_loss: 0.8667
#
# Epoch 00094: val_loss did not improve from 0.60369
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.85it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 57/57 [00:00<00:00, 10328.12it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 655s 655ms/step - loss: 0.7903 - val_loss: 0.8467
#
# Epoch 00095: val_loss did not improve from 0.60369
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.14it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 61/61 [00:00<00:00, 9711.25it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.894
#
#               mAP   0.894
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 651s 651ms/step - loss: 0.7800 - val_loss: 0.5806
#
# Epoch 00096: val_loss improved from 0.60369 to 0.58060, saving model to ssd300_whales_epoch-96_loss-0.7810_val_loss-0.5806.h5
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.52it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 62/62 [00:00<00:00, 4248.44it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.818
#
#               mAP   0.818
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 647s 647ms/step - loss: 0.7725 - val_loss: 0.6741
#
# Epoch 00097: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 12.03it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 59/59 [00:00<00:00, 12809.36it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.905
#
#               mAP   0.905
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 648s 648ms/step - loss: 0.7717 - val_loss: 0.7425
#
# Epoch 00098: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.12it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 59/59 [00:00<00:00, 4170.13it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.9
#
#               mAP   0.9
# Epoch 99/120
#
# Epoch 00099: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 647s 647ms/step - loss: 0.7803 - val_loss: 0.8567
#
# Epoch 00099: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.32it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 64/64 [00:00<00:00, 6845.22it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.893
#
#               mAP   0.893
# Epoch 100/120
#
# Epoch 00100: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 674s 674ms/step - loss: 0.7691 - val_loss: 0.6851
#
# Epoch 00100: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.04it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 57/57 [00:00<00:00, 5109.43it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.9
#
#               mAP   0.9
# Epoch 101/120
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 648s 648ms/step - loss: 0.7630 - val_loss: 0.7514
#
# Epoch 00101: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.05it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 58/58 [00:00<00:00, 3537.49it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.895
#
#               mAP   0.895
# Epoch 102/120
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 634s 634ms/step - loss: 0.7527 - val_loss: 0.7379
#
# Epoch 00102: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.53it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 56/56 [00:00<00:00, 9247.28it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.895
#
#               mAP   0.895
# Epoch 103/120
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 657s 657ms/step - loss: 0.7538 - val_loss: 0.7109
#
# Epoch 00103: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.76it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 58/58 [00:00<00:00, 6288.15it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.895
#
#               mAP   0.895
# Epoch 104/120
#
# Epoch 00104: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 647s 647ms/step - loss: 0.7541 - val_loss: 0.7320
#
# Epoch 00104: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.58it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 58/58 [00:00<00:00, 8548.67it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.895
#
#               mAP   0.895
# Epoch 105/120
#
# Epoch 00105: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 649s 649ms/step - loss: 0.7527 - val_loss: 0.7044
#
# Epoch 00105: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.98it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 55/55 [00:00<00:00, 6256.93it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 106/120
#
# Epoch 00106: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 655s 655ms/step - loss: 0.7380 - val_loss: 0.7565
#
# Epoch 00106: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.14it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 58/58 [00:00<00:00, 3430.73it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 107/120
#
# Epoch 00107: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 650s 650ms/step - loss: 0.7464 - val_loss: 0.7169
#
# Epoch 00107: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  8.00it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 60/60 [00:00<00:00, 3670.04it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 108/120
#
# Epoch 00108: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 646s 646ms/step - loss: 0.7460 - val_loss: 0.6927
#
# Epoch 00108: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.93it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 63/63 [00:00<00:00, 7060.17it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 109/120
#
# Epoch 00109: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 632s 632ms/step - loss: 0.7518 - val_loss: 0.7007
#
# Epoch 00109: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.50it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 61/61 [00:00<00:00, 4926.87it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 110/120
#
# Epoch 00110: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 673s 673ms/step - loss: 0.7445 - val_loss: 0.7174
#
# Epoch 00110: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.35it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 58/58 [00:00<00:00, 7342.66it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 111/120
#
# Epoch 00111: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 653s 653ms/step - loss: 0.7444 - val_loss: 0.6932
#
# Epoch 00111: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 11.71it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 58/58 [00:00<00:00, 8837.81it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 112/120
#
# Epoch 00112: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 656s 656ms/step - loss: 0.7506 - val_loss: 0.6868
#
# Epoch 00112: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.46it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 62/62 [00:00<00:00, 6626.41it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 113/120
#
# Epoch 00113: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 655s 655ms/step - loss: 0.7534 - val_loss: 0.7382
#
# Epoch 00113: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.13it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 61/61 [00:00<00:00, 8365.29it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 114/120
#
# Epoch 00114: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 646s 646ms/step - loss: 0.7462 - val_loss: 0.7011
#
# Epoch 00114: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.58it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 59/59 [00:00<00:00, 8983.99it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 115/120
#
# Epoch 00115: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 659s 659ms/step - loss: 0.7412 - val_loss: 0.7393
#
# Epoch 00115: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.95it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 57/57 [00:00<00:00, 8315.95it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 116/120
#
# Epoch 00116: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 653s 653ms/step - loss: 0.7528 - val_loss: 0.7077
#
# Epoch 00116: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.89it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 59/59 [00:00<00:00, 9148.73it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899
# Epoch 117/120
#
# Epoch 00117: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 647s 647ms/step - loss: 0.7412 - val_loss: 0.7475
#
# Epoch 00117: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.08it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 59/59 [00:00<00:00, 2207.53it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 118/120
#
# Epoch 00118: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 655s 655ms/step - loss: 0.7423 - val_loss: 0.7429
#
# Epoch 00118: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.87it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 59/59 [00:00<00:00, 4665.96it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.902
#
#               mAP   0.902
# Epoch 119/120
#
# Epoch 00119: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 680s 680ms/step - loss: 0.7482 - val_loss: 0.7422
#
# Epoch 00119: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00, 10.37it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 61/61 [00:00<00:00, 8153.36it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.897
#
#               mAP   0.897
# Epoch 120/120
#
# Epoch 00120: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 662s 662ms/step - loss: 0.7356 - val_loss: 0.7724
#
# Epoch 00120: val_loss did not improve from 0.58060
# Number of images in the evaluation dataset: 39
#
# Producing predictions batch-wise: 100%|██████████| 5/5 [00:00<00:00,  9.94it/s]
# Matching predictions to ground truth, class 1/1.: 100%|██████████| 59/59 [00:00<00:00, 4600.21it/s]
# Computing precisions and recalls, class 1/1
# Computing average precision, class 1/1
# whale         AP    0.899
#
#               mAP   0.899

# %% [markdown]
# ## Predicciones

# %%
# Definiendo el generador de predicciones
predict_generator = val_dataset.generate(batch_size=1,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# %%
# Generamos un ejemplo
batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 0 # indice del batch 

print("Imagen:", batch_filenames[i])
print()
print("Cuadro deliminator verdadero:\n")
print(np.array(batch_original_labels[i]))
# Out:
# Imagen: ../ssd_keras/datasets/whales/train/train/3ee9b8b3.jpg
#
# Cuadro deliminator verdadero:
#
# [[  1  52 198 911 438]]

# %%
y_pred = model.predict(batch_images)

y_pred
# Out:
# array([[[ 1.  ,  0.  , -0.08, ...,  0.1 ,  0.2 ,  0.2 ],
#         [ 1.  ,  0.  , -0.06, ...,  0.1 ,  0.2 ,  0.2 ],
#         [ 1.  ,  0.  ,  0.05, ...,  0.1 ,  0.2 ,  0.2 ],
#         ...,
#         [ 1.  ,  0.  , -0.22, ...,  0.1 ,  0.2 ,  0.2 ],
#         [ 1.  ,  0.  , -0.15, ...,  0.1 ,  0.2 ,  0.2 ],
#         [ 1.  ,  0.  , -0.37, ...,  0.1 ,  0.2 ,  0.2 ]]], dtype=float32)

# %%
# Decodificamos las predicciones

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.5,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

y_pred_decoded
# Out:
# [array([[  1.  ,   1.  ,  13.93,  85.14, 260.36, 196.15]])]

# %%
# Las predicciones fueron realizadas en la imágen redimensionada, para visualizar la predicción en la imágen original convertimos las coordenadas.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Cuadro predecido:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])
# Out:
# Cuadro predecido:
#
#    class   conf xmin   ymin   xmax   ymax
# [[  1.   1.  49. 199. 911. 458.]]

# %%
# Mostramos el cuadro predecido en la imagen

colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()
classes = ['background','whale']

plt.figure(figsize=(20,12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

for box in y_pred_decoded_inv[i]:
    xmin = box[2]
    ymin = box[3]
    xmax = box[4]
    ymax = box[5]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':color, 'alpha':1.0})

# %%
# imprimimos las curvas de pérdida
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('épocas')
plt.ylabel('pérdida')
plt.legend();

# %%
model.evaluate_generator(val_generator,steps=ceil(val_dataset_size/batch_size),callbacks=callbacks)
# Out:
# 0.5072600245475769
